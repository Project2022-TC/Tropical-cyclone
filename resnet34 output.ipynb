# %% [markdown]
# !python3 "/content/drive/MyDrive/TCIE/download_agora.py"

# %%
# !python3 "/content/drive/MyDrive/TCIE/splitdataset.py"
# Out:
# Boundary: 10652
# have processed  100  files.
# have processed  200  files.
# have processed  300  files.
# have processed  400  files.
# have processed  500  files.
# have processed  600  files.
# have processed  700  files.
# have processed  800  files.
# have processed  900  files.
# have processed  1000  files.
# have processed  1100  files.
# have processed  1200  files.
# have processed  1300  files.
# have processed  1400  files.
# have processed  1500  files.
# have processed  1600  files.
# have processed  1700  files.
# have processed  1800  files.
# have processed  1900  files.
# have processed  2000  files.
# have processed  2100  files.
# have processed  2200  files.
# have processed  2300  files.
# have processed  2400  files.
# have processed  2500  files.
# have processed  2600  files.
# have processed  2700  files.
# have processed  2800  files.
# have processed  2900  files.
# have processed  3000  files.
# have processed  3100  files.
# ...

# %%
# !python3 "/content/drive/MyDrive/TCIE/train resnet.py"
# Out:
# root /content/drive/MyDrive/TCIE/train_set
# ...

# %%
# !python3 "/content/drive/MyDrive/TCIE/test resnet.py"
# Out:
# Streaming output truncated to the last 5000 lines.
# tys False
# torch.Size([1, 3, 256, 256])
# tensor([[[[ 0.1059,  0.0745,  0.0667,  ..., -0.2157, -0.2157, -0.2157],
#           [ 0.1059,  0.0824,  0.0667,  ..., -0.2157, -0.2157, -0.2157],
#           [ 0.0980,  0.0667,  0.0588,  ..., -0.2157, -0.2157, -0.2157],
#           ...,
#           [ 0.2000,  0.2157,  0.2314,  ...,  0.0745,  0.0275,  0.0196],
#           [ 0.1608,  0.1686,  0.2000,  ...,  0.0510,  0.0196,  0.0353],
#           [ 0.2078,  0.2078,  0.2235,  ...,  0.0510,  0.0196,  0.0510]],
#
#          [[ 0.1059,  0.0745,  0.0667,  ..., -0.2157, -0.2157, -0.2157],
#           [ 0.1059,  0.0824,  0.0667,  ..., -0.2157, -0.2157, -0.2157],
#           [ 0.0980,  0.0667,  0.0588,  ..., -0.2157, -0.2157, -0.2157],
#           ...,
#           [ 0.2000,  0.2157,  0.2314,  ...,  0.0745,  0.0275,  0.0196],
#           [ 0.1608,  0.1686,  0.2000,  ...,  0.0510,  0.0196,  0.0353],
# ...
